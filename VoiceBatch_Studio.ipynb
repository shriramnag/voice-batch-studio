# %% [markdown]
# # 🎙️ **VoiceBatch Studio Pro v4.2 - Final Fix**
# यह नोटबुक आपके सभी Import Errors और Folder Name की गलतियों को खुद ठीक कर देगी।

# %%
# @title 🛠️ Step 1: Install & Auto-Fix Folders
import os, sys, shutil
from IPython.display import clear_output

print("🚀 Cleaning and Cloning... Please wait.")
# %cd /content/
# !rm -rf voice-batch-studio
# !git clone https://github.com/shriramnag/voice-batch-studio.git
# %cd voice-batch-studio

# --- फोल्डर नाम फिक्स करना (माइनस सिंबल की समस्या) ---
print("🔧 Fixing folder names for Python compatibility...")
src_path = "/content/voice-batch-studio/src"
old_folder = os.path.join(src_path, "voice-batch-studio")
new_folder = os.path.join(src_path, "voicebatch_studio")

if os.path.exists(old_folder):
    os.rename(old_folder, new_folder)
    print("✅ Renamed 'voice-batch-studio' to 'voicebatch_studio'")

# --- लाइब्रेरीज़ इंस्टॉल करना ---
print("📦 Installing requirements...")
# !pip install resemble-perth s3tokenizer omegaconf pydub gradio --quiet
# !pip install -r requirements.txt --quiet

# --- पाथ सेट करना ---
os.environ['PYTHONPATH'] = src_path + ":" + os.environ.get('PYTHONPATH', '')
sys.path.append(src_path)

clear_output()
print("✅ Setup Complete! Ab Step 2 run karein.")

# %%
# @title 🚀 Step 2: Run AI Voice Studio
import sys
sys.path.append('/content/voice-batch-studio/src')
# %cd /content/voice-batch-studio

print("🚀 UI Start ho raha hai... Thodi der mein 'Public URL' dikhega.")
# !python app.py --share
