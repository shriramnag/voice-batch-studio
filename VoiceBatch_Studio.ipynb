# %% [markdown]
# # 🎙️ **VoiceBatch Studio Pro v4.2**
#
# Yeh ek professional AI tool hai jo voice cloning, batch processing aur auto-merge features ke saath aata hai.
#
# ### 🏷️ **Credits & License**
# * **Developer**: Shriram Nag
# * **Repository**: [voice-batch-studio](https://github.com/shriramnag/voice-batch-studio)
# * **License**: MIT License
#
# ---

# %%
# @title 🛠️ Step 1: Install Dependencies & Setup
import os
from IPython.display import clear_output

print("🚀 Installing VoiceBatch Studio requirements... Please wait.")

# 1. क्लीन अप और क्लोन
# %cd /content/
# !rm -rf voice-batch-studio
# !git clone https://github.com/shriramnag/voice-batch-studio.git
# %cd voice-batch-studio

# 2. 'perth' एरर को ठीक करने के लिए सही लाइब्रेरी इंस्टॉल करना
print("📦 Fixing dependencies...")
# !pip install resemble-perth --quiet
# !pip install -r requirements.txt --quiet
# !pip install pydub gradio --quiet

clear_output()
print("✅ Setup Complete! Now run the next cell to start the UI.")

# %% [markdown]
# ### ⚠️ **Prevent Colab Sleep**
# Agar aap mobile par hain, toh niche wala cell chalayein taaki Colab session expire na ho.

# %%
#@title ⚡ Prevent Sleep
from IPython.display import Audio, display
import numpy as np
display(Audio(np.array([0] * 3000, dtype=np.int8), rate=3000, autoplay=True, loop=True))

# %%
#@title 🚀 Step 2: Run AI Voice Studio
import os
# %cd /content/voice-batch-studio

# यह कमांड 'public URL' जेनरेट करेगी जिससे आप ब्राउज़र में ऐप चला सकेंगे
# !python app.py --share
