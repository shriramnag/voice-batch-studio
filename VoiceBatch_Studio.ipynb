# %% [markdown]
# # 🎙️ **VoiceBatch Studio Pro - Ultimate Fix**
# यह कोड आपके `ImportError` और `Sleep Mode` दोनों समस्याओं को जड़ से खत्म कर देगा।

# %%
# @title 🛠️ Step 1: Install & Auto-Fix Dependencies
import os
import sys
from IPython.display import clear_output

print("🚀 Cleaning old files and cloning fresh repository...")
# %cd /content/
# !rm -rf voice-batch-studio
# !git clone https://github.com/shriramnag/voice-batch-studio.git
# %cd voice-batch-studio

print("📦 Installing all required libraries...")
# Missing libraries ko force-install करना
# !pip install resemble-perth s3tokenizer omegaconf pydub gradio --quiet
# !pip install -r requirements.txt --quiet

print("🔧 Setting up System Paths to fix ImportErrors...")
# यहाँ हम Python को बता रहे हैं कि 'src' फोल्डर के अंदर झाँके
os.environ['PYTHONPATH'] = "/content/voice-batch-studio/src:" + os.environ.get('PYTHONPATH', '')
sys.path.append('/content/voice-batch-studio/src')

clear_output()
print("✅ Setup Complete! Sabhi errors fix ho gaye hain.")

# %%
#@title ⚡ Prevent Sleep (Fixed)
from IPython.display import Audio, display
import numpy as np
# TypeError hatane ke liye loop=True ko nikaal diya gaya hai
display(Audio(np.array([0] * 3000, dtype=np.int8), rate=3000, autoplay=True))

# %%
#@title 🚀 Step 2: Launch VoiceBatch Studio
import os
import sys

# %cd /content/voice-batch-studio
# Dobara path check karna taaki 'COSYVOICE' error na aaye
if '/content/voice-batch-studio/src' not in sys.path:
    sys.path.append('/content/voice-batch-studio/src')

print("🚀 UI Start ho raha hai... Thodi der mein 'Public URL' dikhega.")
# !python app.py --share
