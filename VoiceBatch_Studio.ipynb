# %%
# @title 🛠️ Step 1: Install & Auto-Fix Folder Names
import os, sys
from IPython.display import clear_output

# %cd /content/
# !rm -rf voicebatch-studio
# !git clone https://github.com/shriramnag/voicebatch-studio.git
# %cd voice-batch-studio

# यह लाइन माइनस वाले फोल्डर को सही नाम में बदल देगी
if os.path.exists('src/voicebatch-studio'):
    os.rename('src/voicebatch-studio', 'src/voicebatch_studio')

# !pip install resemble-perth s3tokenizer omegaconf pydub gradio --quiet
# !pip install -r requirements.txt --quiet

os.environ['PYTHONPATH'] = "/content/voicebatch-studio/src:" + os.environ.get('PYTHONPATH', '')
sys.path.append('/content/voicebatch-studio/src')

clear_output()
print("✅ Setup Complete! Folder names fixed.")

# %%
# @title 🚀 Step 2: Run App
# %cd /content/voicebatch-studio
# !python app.py --share
