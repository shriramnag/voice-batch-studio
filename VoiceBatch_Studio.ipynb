# %% [markdown]
# # 🎙️ **VoiceBatch Studio Pro v4.2**
#
# Yeh ek professional AI tool hai jo voice cloning, batch processing aur auto-merge features ke saath aata hai.
#
# ### 🏷️ **Credits & License**
# * **Developer**: Shriram Nag
# * **Repository**: [voice-batch-studio](https://github.com/shriramnag/voice-batch-studio)
# * **License**: MIT License
#
# ---

# %%
# @title 🛠️ Step 1: Install Dependencies & Setup
import os
from IPython.display import clear_output

print("🚀 Installing VoiceBatch Studio requirements... Please wait.")

# 1. क्लीन अप और क्लोन
# %cd /content/
# !rm -rf voice-batch-studio
# !git clone https://github.com/shriramnag/voice-batch-studio.git
# %cd voice-batch-studio

# 2. 'perth' और 's3tokenizer' एरर को जड़ से खत्म करने के लिए इंस्टॉलेशन
print("📦 Fixing all dependencies (perth, s3tokenizer, etc.)...")
# !pip install resemble-perth s3tokenizer --quiet
# !pip install -r requirements.txt --quiet
# !pip install pydub gradio --quiet

clear_output()
print("✅ Setup Complete! Sab kuch sahi se install ho gaya hai.")
print("Ab niche wale cells ko run karein.")

# %% [markdown]
# ### ⚠️ **Prevent Colab Sleep**
# Agar aap mobile par hain, toh niche wala cell chalayein taaki connection cut na ho.

# %%
#@title ⚡ Prevent Sleep (Fixed Code)
from IPython.display import Audio, display
import numpy as np

# TypeError: loop=True ko hata diya gaya hai taaki error na aaye
display(Audio(np.array([0] * 3000, dtype=np.int8), rate=3000, autoplay=True))

# %%
#@title 🚀 Step 2: Run AI Voice Studio
import os
# %cd /content/voice-batch-studio

print("🚀 UI Start ho raha hai... Thodi der mein 'Public URL' dikhega.")
# app.py ko run karna
# !python app.py --share
